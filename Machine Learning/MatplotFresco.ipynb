# %% [markdown]
# # Parts of a Matplotlib Figure
# In this topic, you will get introduced to essential parts of a Matplotlib Figure.
#
# Figure: Whole area chosen for plotting.
#
# 1.   Axes: Area where data is plotted.
# 2.   Axis: Number-line like objects, which define graph limits.
# 3. Artist: Every element on the figure is an artist.

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.show()

# %% [markdown]
# # Axes
# An Axes is the region of the figure, available for plotting data.
#
# An Axes object is associated with only one Figure.
#
# A Figure can contain one or more number of Axes elements.
#
# An Axes contains two Axis objects in case of 2D plots and three Axis objects in case of 3D plots.

# %%
fig = plt.figure()
# add_subplot(nrows, ncols, index)
#add_subplot(1, 1, 1)
ax = fig.add_subplot(111)
plt.show()

# %% [markdown]
# The default width and height of a figure are 6 and 4 inches respectively.
#
# For example, the expression
#
# ```
# fig = plt.figure(figsize=(8,6))
#
# ```
#
#  generates a figure having 8 inches width and 6 inches height.

# %% [markdown]
# **Set method can be used on created axes, ax, to set various parameters such as xlabel, ylabel and title.**

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='My First Plot',
      xlabel='X-Axis', ylabel='Y-Axis',
      xlim=(0, 5), ylim=(0,10))
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set_title("My First Plot")
ax.set_xlabel("X-Axis"); ax.set_ylabel('Y-Axis')
ax.set_xlim([0,5]); ax.set_ylim([0,10])
plt.show()

# %% [markdown]
# plot is one of the functions used for plotting data points.
#
# plot function is called on the created axes object, ax, as shown in below code snippet.

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='My First Plot',
      xlabel='X-Axis', ylabel='Y-Axis',
      xlim=(0, 5), ylim=(0,10))
x = [1, 2, 3, 4]; y = [2, 4, 6, 8]
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Labelling Plot, use this

# %%
fig = plt.figure(figsize=(8,6))

x = [1, 2, 3, 4]; y = [2, 4, 6, 8]
plt.plot(x, y)
plt.title('My First Plot')
plt.xlabel('X-Axis'); plt.ylabel('Y-Axis')
plt.xlim(0,5); plt.ylim(0,10)
plt.plot(x, y)
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='My First Plot',
      xlabel='X-Axis', ylabel='Y-Axis',
      xlim=(0, 5), ylim=(0,10))
x = [1, 2, 3, 4]; y = [2, 4, 6, 8]
plt.plot(x, y, label='linear-growth')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot([10, 12, 14, 16])
plt.show()

# %% [markdown]
# # TESTS HANDS-ON

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Time vs Distance Covered',
      xlabel='time (seconds)', ylabel='distance (meters)',
      xlim=(0, 30), ylim=(0,130))
t = [5, 10, 15, 20, 25]; d = [25, 50, 75, 100, 125]
plt.plot(t, d, label='d = 5t')
plt.legend()
plt.show()

# %% [markdown]
# # Line

# %%
#plot(x, y)
# 'x' , 'y' : Data values representing two variables.

fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Daily Temperature in Jan 2018',
      xlabel='Day', ylabel='Temperature (in deg)',
      xlim=(0, 30), ylim=(25, 35))
days = [1, 5, 8, 12, 15, 19, 22, 26, 29]
temp = [29.3, 30.1, 30.4, 31.5, 32.3, 32.6, 31.8, 32.4, 32.7]
ax.plot(days, temp)
plt.show()

# %% [markdown]
# **Multiple Plots**

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Daily Temperature of Jan 2018',
      xlabel='Day', ylabel='Temperature (in deg)',
      xlim=(0, 30), ylim=(25, 35))
days = [1, 5, 8, 12, 15, 19, 22, 26, 29]
location1_temp = [29.3, 30.1, 30.4, 31.5, 32.3, 32.6, 31.8, 32.4, 32.7]
location2_temp = [26.4, 26.8, 26.1, 26.4, 27.5, 27.3, 26.9, 26.8, 27.0]
ax.plot(days, location1_temp, color='green', marker='o', linewidth=3)
ax.plot(days, location2_temp, color='red', marker='o', linewidth=3)
plt.show()

# %% [markdown]
# # Scatter
# scatter plot only marks the data points with the chosen marker.

# %%
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Daily Temperature of Jan 2018',
      xlabel='Day', ylabel='Temperature (in deg)',
      xlim=(0, 30), ylim=(25, 35))
days = [1, 5, 8, 12, 15, 19, 22, 26, 29]
temp = [29.3, 30.1, 30.4, 31.5, 32.3, 32.6, 31.8, 32.4, 32.7]
ax.scatter(days, temp)
plt.show()

# %%
ax.scatter(days, temp, marker='o', c=['green'], s=[60], edgecolor='black')
plt.show()

# %% [markdown]
# # LINE and SCATTER TEST

# %%
#from matplotlib.ticker import (MultipleLocator, FixedLocator, FormatStrFormatter, AutoMinorLocator)
#ax.xaxis.set_major_locator(FixedLocator([1, 3, 5, 7, 9, 11]))

import matplotlib.pyplot as plt
fig = plt.figure(figsize=(12,3))
ax = fig.add_subplot(111)
import numpy as np
t = np.linspace(0.0,2.0,200)
v = np.sin(2.5*np.pi*t)
plt.plot(t, v, label='sin(t)', color='red')
ax.set(title='Sine Wave',
      xlabel='Time (seconds)', ylabel='Voltage (mV)',
      xlim=(0, 2), ylim=(-1,1), xticks=(np.arange(0,2.2,0.2)), yticks=(-1,0,1))
plt.grid(linestyle='--')
plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(12,3))
ax = fig.add_subplot(111)
import numpy as np
x = np.linspace(0,5, num=20)
y1 = x
y2 = x**2
y3 = x**3
ax.set(title='Linear, Quadratic, & Cubic Equations',
      xlabel='X', ylabel='f(X)')
plt.plot(x, y1, label='y = x', color='red',marker='o')
plt.plot(x, y2, label='y = x**2', color='green',marker='s')
plt.plot(x, y3, label='y = x**3', color='blue',marker='^')
plt.legend()
plt.show()

# %%
import numpy as np
fig = plt.figure(figsize=(12,3))
ax = fig.add_subplot(111)
s = [50, 60, 55, 50, 70, 65, 75, 65, 80, 90, 93, 95]
months = np.arange(1,13)
ax.scatter(months, s, c=['red'])
ax.set(title="Cars Sold by Company 'X' in 2017",
      xlabel='Months', ylabel='No. of Cars Sold',
      xlim=(0, 13), ylim=(20, 100), xticks=(np.arange(1,13,2)), xticklabels=('Jan', 'Mar', 'May', 'Jul', 'Sep', 'Nov'))
plt.show()

# %% [markdown]
# # Bar Plot

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Quarterly Sales',
      xlabel='Quarter', ylabel='Sales (in millions)')
quarters = [1, 2, 3]
sales_2017 = [25782, 35783, 36133]
ax.bar(quarters, sales_2017)
ax.set_xticks(quarters)
ax.set_xticklabels(['Q1-2017', 'Q2-2017', 'Q3-2017'])
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Quarterly Sales',
      xlabel='Quarter', ylabel='Sales (in millions)')
quarters = [1, 2, 3]
x1_index = [0.8, 1.8, 2.8]; x2_index = [1.2, 2.2, 3.2]
sales_2016 = [28831, 30762, 32178]; sales_2017 = [25782, 35783, 36133]
ax.bar(x1_index, sales_2016, color='yellow', width=0.4, edgecolor='black', label='2016')
ax.bar(x2_index, sales_2017, color='red', width=0.4, edgecolor='black', label='2017')
ax.set_xticks(quarters)
ax.set_xticklabels(['Q1', 'Q2', 'Q3'])
ax.legend()
plt.show()

# %% [markdown]
# barh draws the bars horizontally as shown in above image.
#
# height parameter is used to adjust the height of each bar.
#
# Horizontal bar plots are used while comparing values of one category at a time.

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Quarterly Sales',
      xlabel='Sales (in millions)', ylabel='Quarter')
quarters = [1, 2, 3]
sales_2017 = [25782, 35783, 36133]
ax.barh(quarters, sales_2017, height=0.6, color='red')
ax.set_yticks(quarters)
ax.set_yticklabels(['Q1-2017', 'Q2-2017', 'Q3-2017'])
plt.show()

# %% [markdown]
# # Pie Plot

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111)
ax.set(title='Avg. Quarterly Sales')
sales_2017 = [25782, 35783, 36133]
quarters = ['Q1-2017', 'Q2-2017', 'Q3-2017']
ax.pie(sales_2017, labels=quarters, startangle=90, autopct='%1.1f%%')
plt.show()

# %% [markdown]
# # Bar Test

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
species  = ['setosa', 'versicolor', 'viriginica']
index = [0.2, 1.2, 2.2]
sepal_len = [5.01, 5.94, 6.59]

ax.set(title="Mean Sepal Length of Iris Species",
      xlabel='Species', ylabel='Sepal Length (cm)',
      xlim=(0, 3), ylim=(0, 7), xticks=(0.45,1.45,2.45), xticklabels=(species))

ax.bar(index, sepal_len, color='red', width=0.5, edgecolor = 'black')
#plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
species  = ['setosa', 'versicolor', 'viriginica']

sepal_len = [5.01, 5.94, 6.59]
sepal_wd = [3.42, 2.77, 2.97]
petal_len = [1.46, 4.26, 5.55]
petal_wd = [0.24, 1.33, 2.03]

species_index1 = [0.7, 1.7, 2.7]
species_index2 = [0.9, 1.9, 2.9]
species_index3 = [1.1, 2.1, 3.1]
species_index4 = [1.3, 2.3, 3.3]

plt.bar()

ax.set(title="Mean Measurements of Iris Species",
      xlabel='Species', ylabel='Iris Measurements (cm)',
      xlim=(0.5, 3.7), ylim=(0, 10), xticks=(1.1,2.1,3.1), xticklabels=(species))

ax.bar(species_index1, sepal_len, label='Sepal Length', color='c', width=0.2, edgecolor = 'black', )
ax.bar(species_index2, sepal_wd, label='Sepal Width', color='m', width=0.2, edgecolor = 'black')
ax.bar(species_index3, petal_len, label='Petal Length', color='y', width=0.2, edgecolor = 'black')
ax.bar(species_index4, petal_wd, label='Petal Width', color='orange', width=0.2, edgecolor = 'black')

plt.legend()
plt.show()

# %%
fig = plt.figure(figsize=(12,5))
ax = fig.add_subplot(111)
species  = ['setosa', 'versicolor', 'viriginica']

index = [0.2, 1.2, 2.2]
petal_len = [1.46, 4.26, 5.55]

ax.barh(index, petal_len, color='c', height=0.5, edgecolor = 'black')

ax.set(title="Mean Petal Length of Iris Species",
      xlabel='Petal Length (cm)', ylabel='Species',
      yticks=(0.45,1.45,2.45), yticklabels=(species))
plt.show()

# %% [markdown]
# # HISTOGRAM
# Histogram is used to visualize the spread of data of a distribution.
#
# The below example simulates 1000 percentage values from a normal distribution with mean 60 and standard deviation 10.

# %%
import numpy as np
np.random.seed(100)
x = 60 + 10*np.random.randn(1000)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title="Distribution of Student's Percentage",
      ylabel='Count', xlabel='Percentage')
ax.hist(x)
plt.show()

# %%
import numpy as np
np.random.seed(100)
x = 60 + 10*np.random.randn(1000)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title="Distribution of Student's Percentage",
      ylabel='Proportion', xlabel='Percentage')
ax.hist(x, color='blue', bins=30, normed=True)
plt.show()

# %% [markdown]
# # BOX PLOT

# %%
import numpy as np
np.random.seed(100)
x = 50 + 10*np.random.randn(1000)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title="Box plot of Student's Percentage",
      xlabel='Class', ylabel='Percentage')
ax.boxplot(x)
plt.show()

# %% [markdown]
# Box plot of Student Percentages can be redrawn by setting notch, bootstrap and labels using the below-shown expression.

# %%
import numpy as np
np.random.seed(100)
x = 50 + 10*np.random.randn(1000)
y = 70 + 25*np.random.randn(1000)
z = 30 + 5*np.random.randn(1000)
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
ax.set(title="Box plot of Student's Percentage",
      xlabel='Class', ylabel='Percentage')
ax.boxplot([x, y, z], labels=['A', 'B', 'C'], notch=True, bootstrap=10000)
plt.show()

# %% [markdown]
# # HISTOGRAM TEST

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
import numpy as np
np.random.seed(100)
x1 = 25 + 3*np.random.randn(1000)
plt.hist(x1, bins=30)
ax.set(title="Histogram of a Single Dataset",
      xlabel='X1', ylabel='Bin Count')
plt.show()

# %%
fig = plt.figure(figsize=(8,6))
ax = fig.add_subplot(111)
import numpy as np
np.random.seed(100)
x1 = 25 + 3*np.random.randn(1000)
x2 = 35 + 5*np.random.randn(1000)
x3 = 55 + 10*np.random.randn(1000)
x4 = 45 + 3*np.random.randn(1000)
labels = ['X1', 'X2', 'X3', 'X4']


plt.boxplot([x1,x2,x3,x4], labels=labels, sym='+', notch=True,patch_artist=True,)
ax.set(title="Box plot of Multiple Datasets",
      xlabel='Dataset', ylabel='Value')
plt.show()

# %% [markdown]
# # STYLES

# %%
import matplotlib.pyplot as plt
print(plt.style.available)
# Out:
# ['bmh', 'fast', 'seaborn-muted', 'seaborn-dark-palette', 'seaborn-colorblind', 'seaborn-whitegrid', 'seaborn-paper', 'seaborn-deep', 'tableau-colorblind10', 'seaborn-darkgrid', 'seaborn-poster', 'dark_background', 'seaborn-talk', 'seaborn-pastel', '_classic_test', 'grayscale', 'seaborn-ticks', 'seaborn-notebook', 'seaborn-dark', 'classic', 'fivethirtyeight', 'ggplot', 'Solarize_Light2', 'seaborn', 'seaborn-white', 'seaborn-bright']

# %%
  with plt.style.context('ggplot'):
    fig = plt.figure(figsize=(8,6))
    ax = fig.add_subplot(111)
    ax.set(title='Avg. Daily Temperature of Jan 2018',
      xlabel='Day', ylabel='Temperature (in deg)',
      xlim=(0, 30), ylim=(25, 35))
    days = [1, 5, 8, 12, 15, 19, 22, 26, 29]
    temp = [29.3, 30.1, 30.4, 31.5, 32.3, 32.6, 31.8, 32.4, 32.7]
    ax.plot(days, temp, 'bo', linestyle='--', linewidth=3)
    plt.show()

# %% [markdown]
# A style sheet is a text file having extension .mplstyle.
#
# All custom style sheets are placed in a folder, stylelib, present in the config directory of matplotlib.

# %%
import matplotlib
print(matplotlib.get_configdir())

# %%
import matplotlib as mpl
mpl.rcParams['lines.linewidth'] = 2
mpl.rcParams['lines.color'] = 'r'

# %% [markdown]
# # STYLE TEST

# %%
import matplotlib.pyplot as plt
import numpy as np
with plt.style.context('ggplot'):
  fig = plt.figure(figsize=(8,6))
  ax = fig.add_subplot(111)
  species  = ['setosa', 'versicolor', 'viriginica']


  sepal_len = [5.01, 5.94, 6.59]
  sepal_wd = [3.42, 2.77, 2.97]
  petal_len = [1.46, 4.26, 5.55]
  petal_wd = [0.24, 1.33, 2.03]
  
  species_index1 = [0.7, 1.7, 2.7]
  species_index2 = [0.9, 1.9, 2.9]
  species_index3 = [1.1, 2.1, 3.1]
  species_index4 = [1.3, 2.3, 3.3]


  ax.set(title="Mean Measurements of Iris Species",
      xlabel='Species', ylabel='Iris Measurements (cm)',
      xlim=(0.5, 3.7), ylim=(0, 10), xticks=(1.1,2.1,3.1), xticklabels=(species))

  ax.bar(species_index1, sepal_len, label='Sepal Length', color='c', width=0.2, edgecolor = 'black', )
  ax.bar(species_index2, sepal_wd, label='Sepal Width', color='m', width=0.2, edgecolor = 'black')
  ax.bar(species_index3, petal_len, label='Petal Length', color='y', width=0.2, edgecolor = 'black')
  ax.bar(species_index4, petal_wd, label='Petal Width', color='orange', width=0.2, edgecolor = 'black')

  plt.legend()
  plt.show()

# %%
with plt.style.context('seaborn-colorblind'):
  fig = plt.figure(figsize=(8,6))
  ax = fig.add_subplot(111)
  species  = ['setosa', 'versicolor', 'viriginica']


  sepal_len = [5.01, 5.94, 6.59]
  sepal_wd = [3.42, 2.77, 2.97]
  petal_len = [1.46, 4.26, 5.55]
  petal_wd = [0.24, 1.33, 2.03]
  
  species_index1 = [0.7, 1.7, 2.7]
  species_index2 = [0.9, 1.9, 2.9]
  species_index3 = [1.1, 2.1, 3.1]
  species_index4 = [1.3, 2.3, 3.3]


  ax.set(title="Mean Measurements of Iris Species",
      xlabel='Species', ylabel='Iris Measurements (cm)',
      xlim=(0.5, 3.7), ylim=(0, 10), xticks=(1.1,2.1,3.1), xticklabels=(species))

  ax.bar(species_index1, sepal_len, label='Sepal Length', color='c', width=0.2, edgecolor = 'black', )
  ax.bar(species_index2, sepal_wd, label='Sepal Width', color='m', width=0.2, edgecolor = 'black')
  ax.bar(species_index3, petal_len, label='Petal Length', color='y', width=0.2, edgecolor = 'black')
  ax.bar(species_index4, petal_wd, label='Petal Width', color='orange', width=0.2, edgecolor = 'black')

  plt.legend()
  plt.show()

# %%
with plt.style.context('grayscale'):
  fig = plt.figure(figsize=(8,6))
  ax = fig.add_subplot(111)
  species  = ['setosa', 'versicolor', 'viriginica']


  sepal_len = [5.01, 5.94, 6.59]
  sepal_wd = [3.42, 2.77, 2.97]
  petal_len = [1.46, 4.26, 5.55]
  petal_wd = [0.24, 1.33, 2.03]
  
  species_index1 = [0.7, 1.7, 2.7]
  species_index2 = [0.9, 1.9, 2.9]
  species_index3 = [1.1, 2.1, 3.1]
  species_index4 = [1.3, 2.3, 3.3]


  ax.set(title="Mean Measurements of Iris Species",
      xlabel='Species', ylabel='Iris Measurements (cm)',
      xlim=(0.5, 3.7), ylim=(0, 10), xticks=(1.1,2.1,3.1), xticklabels=(species))

  ax.bar(species_index1, sepal_len, label='Sepal Length', color='c', width=0.2, edgecolor = 'black', )
  ax.bar(species_index2, sepal_wd, label='Sepal Width', color='m', width=0.2, edgecolor = 'black')
  ax.bar(species_index3, petal_len, label='Petal Length', color='y', width=0.2, edgecolor = 'black')
  ax.bar(species_index4, petal_wd, label='Petal Width', color='orange', width=0.2, edgecolor = 'black')

  plt.legend()
  plt.show()

# %% [markdown]
# # Multiplots

# %%
fig = plt.figure(figsize=(10,8))
axes1 = plt.subplot(2, 2, 1, title='Plot1')
axes2 = plt.subplot(2, 2, 2, title='Plot2')
axes3 = plt.subplot(2, 2, 3, title='Plot3')
axes4 = plt.subplot(2, 2, 4, title='Plot4')
plt.suptitle('goodbot')
plt.show()

# %% [markdown]
# USING GRID
# The below example recreates the previous figure using GridSpec.
#
# A GridSpec object, gd is created with two rows and two columns.
#
# Then a selected grid portion is passed as an argument to subplot.

# %%
import matplotlib.gridspec as gridspec
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(10,8))
gd = gridspec.GridSpec(2,2)
axes1 = plt.subplot(gd[0,:],title='Plot1')
axes1.set_xticks([]); axes1.set_yticks([])
axes2 = plt.subplot(gd[1,0])
axes2.set_xticks([]); axes2.set_yticks([])
axes3 = plt.subplot(gd[1,-1])
axes3.set_xticks([]); axes3.set_yticks([])
plt.show()

# %% [markdown]
# **Complex Layout**

# %%
fig = plt.figure(figsize=(12,10))
gd = gridspec.GridSpec(3,3)
axes1 = plt.subplot(gd[0,:],title='Plot1')
axes1.set_xticks([]); axes1.set_yticks([])
axes2 = plt.subplot(gd[1,:-1], title='Plot2')
axes2.set_xticks([]); axes2.set_yticks([])
axes3 = plt.subplot(gd[1:, 2], title='Plot3')
axes3.set_xticks([]); axes3.set_yticks([])
axes4 = plt.subplot(gd[2, :-1], title='Plot4')
axes4.set_xticks([]); axes4.set_yticks([])
plt.show()

# %% [markdown]
# # Multiplot Test

# %%
t = np.arange(0.0, 5.0, 0.01)
s1 = np.sin(2*np.pi*t)
s2 = np.sin(4*np.pi*t)

fig = plt.figure(figsize=(8,6))
#gd = gridspec.GridSpec(2,1)
axes1 = plt.subplot(2,1,1,title='Sin(2*pi*x)')
axes1.plot(t,s1)
axes2 = plt.subplot(2,1,2, sharex=axes1, sharey=axes1, title='Sin(4*pi*x)')
axes2.plot(t,s2)

# %%
import numpy as np
np.random.seed(1000)
x = np.random.rand(10)
y = np.random.rand(10)
z = np.sqrt(x**2 + y**2)

fig = plt.figure(figsize=(8,6))

axes1 = plt.subplot(2,2,1,title='Scatter plot with Upper Traingle Markers')
axes1.scatter(x,y,c=z,s=80,marker='^')
axes1.set(xticks=(0.0, 0.4, 0.8, 1.2), yticks=(-0.2, 0.2, 0.6, 1.0))
axes2 = plt.subplot(2,2,2,title='Scatter plot with Plus Markers')
axes2.scatter(x,y,c=z,s=80,marker='+')
axes2.set(xticks=(0.0, 0.4, 0.8, 1.2), yticks=(-0.2, 0.2, 0.6, 1.0))
axes3 = plt.subplot(2,2,3,title='Scatter plot with Circle Markers')
axes3.scatter(x,y,c=z,s=80,marker='o')
axes3.set(xticks=(0.0, 0.4, 0.8, 1.2), yticks=(-0.2, 0.2, 0.6, 1.0))
axes4 = plt.subplot(2,2,4,title='Scatter plot with Diamond Markers')
axes4.scatter(x,y,c=z,s=80,marker='d')
axes4.set(xticks=(0.0, 0.4, 0.8, 1.2), yticks=(-0.2, 0.2, 0.6, 1.0))
plt.tight_layout()

# %%
x = np.arange(1, 101)
y1 = x
y2 = x**2
y3 = x**3
fig = plt.figure(figsize=(8,6))

import matplotlib.gridspec as gridspec
g = gridspec.GridSpec(2,2)
axes1 = plt.subplot(g[0,0],title='y = x')
axes1.plot(x,y1)
axes2 = plt.subplot(g[1,0],title='y = x*2')
axes2.plot(x,y2)
axes3 = plt.subplot(g[:,1],title='y = x**3')
axes3.plot(x,y3)
plt.tight_layout()

# %% [markdown]
# matplotlib can generate plots in different outputs.
#
# In general, backend refers to everything that occurs from the time of executing a plotting code to generating the figure.
#
# Backends are of two types.
#
# interactive backends: Graphical user interfaces like PyGTK, wxPython, Tkinter, qt4, etc.
# non-interactive backends: Image files such as PNG, JPEG, etc.
#
#
#
# The default backend chosen by matplotlib is available as backend setting in matplotlibrc file.
#
# If you want to alter the backend of many figures, change the value of backend setting.
#
# The below expression chooses WXAgg backend.

# %%
import matplotlib
matplotlib.use('WXAgg') 
# Above expression must be used before importing pylot
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-b15bf53a71d8> in <module>()
#       1 import matplotlib
# ----> 2 matplotlib.use('WXAgg')
#       3 # Above expression must be used before importing pylot
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/__init__.py in use(arg, warn, force)
#    1389         if force:
#    1390             from matplotlib.pyplot import switch_backend
# -> 1391             switch_backend(name)
#    1392     # Finally if pyplot is not imported update both rcParams and
#    1393     # rcDefaults so restoring the defaults later with rcdefaults
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/pyplot.py in switch_backend(newbackend)
#     205         else "matplotlib.backends.backend_{}".format(newbackend.lower()))
#     206
# --> 207     backend_mod = importlib.import_module(backend_name)
#     208     Backend = type(
#     209         "Backend", (matplotlib.backends._Backend,), vars(backend_mod))
#
# /usr/lib/python3.6/importlib/__init__.py in import_module(name, package)
#     124                 break
#     125             level += 1
# --> 126     return _bootstrap._gcd_import(name[level:], package, level)
#     127
#     128
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /usr/lib/python3.6/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /usr/lib/python3.6/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_wxagg.py in <module>()
# ----> 1 import wx
#       2
#       3 from .backend_agg import FigureCanvasAgg
#       4 from .backend_wx import (
#       5     _BackendWx, _FigureCanvasWxBase, FigureFrameWx,
#
# ModuleNotFoundError: No module named 'wx'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# Once a backend is chosen, a matplotlib figure can be saved in any format supported by it.
#
# The below shown example saves the plot in png format.

# %%
fig = plt.figure(figsize(8,6))
ax = fig.add_subplot(111)
ax.set(title='My First Plot',
      xlabel='X-Axis', ylabel='Y-Axis',
      xlim=(0, 5), ylim=(0,10))
x = [1, 2, 3, 4]; y = [2, 4, 6, 8]
plt.plot(x, y)
plt.figsave('myplot.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c5eb7ee918e5> in <module>()
# ----> 1 fig = plt.figure(figsize(8,6))
#       2 ax = fig.add_subplot(111)
#       3 ax.set(title='My First Plot',
#       4       xlabel='X-Axis', ylabel='Y-Axis',
#       5       xlim=(0, 5), ylim=(0,10))
#
# NameError: name 'figsize' is not defined
